# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dansbecker/food-101")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\yueya\.cache\kagglehub\datasets\dansbecker\food-101\versions\1

# %%
import os

print(os.listdir(path))
# Out:
# ['food-101', 'food-101.zip']

# %%
from torchvision import datasets, transforms

data_dir = path + "/food-101/food-101/images"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(data_dir, transform=transform)

print(len(dataset))
print(dataset.classes[:5])
# Out:
# 101000
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare']

# %%
from IPython.display import display
from torchvision.transforms.functional import to_pil_image

for i in range(5):
    img, label = dataset[i]
    img = to_pil_image(img)
    
    print(dataset.classes[label])
    display(img)
# Out:
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.models import vit_b_16, ViT_B_16_Weights

# %%
weights = ViT_B_16_Weights.IMAGENET1K_V1

transform = weights.transforms()

# %%
import os
from PIL import Image
from torch.utils.data import Dataset

class Food101Dataset(Dataset):
    def __init__(self, root, split_file, transform=None):
        self.root = root
        self.transform = transform
        
        with open(split_file) as f:
            self.samples = f.read().splitlines()
        
        self.classes = sorted(set(x.split('/')[0] for x in self.samples))
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        item = self.samples[idx]
        label_name = item.split('/')[0]
        
        img_path = os.path.join(self.root, "images", item + ".jpg")
        img = Image.open(img_path).convert("RGB")
        
        if self.transform:
            img = self.transform(img)
        
        label = self.class_to_idx[label_name]
        return img, label

# %%
base_path = path + "/food-101/food-101"

train_dataset = Food101Dataset(
    root=base_path,
    split_file=base_path + "/meta/train.txt",
    transform=transform
)

test_dataset = Food101Dataset(
    root=base_path,
    split_file=base_path + "/meta/test.txt",
    transform=transform
)

# %%
model = vit_b_16(weights=weights)
model.heads.head = nn.Linear(model.heads.head.in_features, 101)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)
# Out:
# cuda

# %%
criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.heads.parameters(), lr=1e-3)

# %% [markdown]
# Made an Early Stopping function for training

# %%
class EarlyStopping:
    def __init__(self, patience=3, min_delta=0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float('inf')
        self.counter = 0
        self.early_stop = False

    def __call__(self, val_loss):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
def evaluate_loss(model, loader):
    model.eval()
    total_loss = 0
    
    with torch.no_grad():
        for imgs, labels in loader:
            imgs, labels = imgs.to(device), labels.to(device)
            
            outputs = model(imgs)
            loss = criterion(outputs, labels)
            total_loss += loss.item()
    
    return total_loss / len(loader)

# %%
from torch.utils.data import random_split

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=0, pin_memory = True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=0, pin_memory = True)

# %% [markdown]
# Below is a debug line to check if everything is running on the GPU (I had problems with kernel stalls/crashes)

# %%
imgs, labels = next(iter(train_loader))
imgs = imgs.to(device)

print("DEBUG:", imgs.device, next(model.parameters()).device)
# Out:
# DEBUG: cuda:0 cuda:0

# %%
import torch
import time

def train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=20,
    patience=3,
    save_path="best_linear_model_vit.pth"
):
    best_val_loss = float('inf')
    counter = 0

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_acc": [],
        "epoch_time": []
    }

    total_start = time.time()  # Total training time

    for epoch in range(epochs):
        epoch_start = time.time()  # Start epoch timer

        # Train
        model.train()
        train_loss = 0

        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validate
        model.eval()
        val_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)

                outputs = model(imgs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()

                preds = outputs.argmax(dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        val_loss /= len(val_loader)
        val_acc = correct / total

        # Compute epoch time
        epoch_time = time.time() - epoch_start
        history["epoch_time"].append(epoch_time)
        
        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_loss:.4f} | "
              f"Val Loss: {val_loss:.4f} | "
              f"Val Acc: {val_acc:.4f} | "
              f"Time: {epoch_time:.2f}s")

        # Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0

            torch.save(model.state_dict(), save_path)
            print("Best model saved")

        else:
            counter += 1
            print(f"No improvement ({counter}/{patience})")

            if counter >= patience:
                print("Early stopping triggered")
                break

    # Total time
    total_time = time.time() - total_start
    print(f"\nTotal training time: {total_time:.2f}s")

    history["total_time"] = total_time

    return history

# %% [markdown]
# First we start with linear probing, which is freezing all parameters and then unfreezing just the classifier

# %%
for param in model.parameters():
    param.requires_grad = False

for param in model.heads.parameters():
    param.requires_grad = True

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2
)

#Save history locally in case of kernel crash
with open("history_linear.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.8447 | Val Loss: 1.3806 | Val Acc: 0.6481 | Time: 617.73s
# Best model saved
# Epoch 2/50 | Train Loss: 1.2217 | Val Loss: 1.2273 | Val Acc: 0.6853 | Time: 625.46s
# Best model saved
# Epoch 3/50 | Train Loss: 1.0685 | Val Loss: 1.1742 | Val Acc: 0.6958 | Time: 630.84s
# Best model saved
# Epoch 4/50 | Train Loss: 0.9772 | Val Loss: 1.1386 | Val Acc: 0.7051 | Time: 629.49s
# Best model saved
# Epoch 5/50 | Train Loss: 0.9117 | Val Loss: 1.1337 | Val Acc: 0.7033 | Time: 627.96s
# Best model saved
# Epoch 6/50 | Train Loss: 0.8613 | Val Loss: 1.1125 | Val Acc: 0.7086 | Time: 625.61s
# Best model saved
# Epoch 7/50 | Train Loss: 0.8219 | Val Loss: 1.1104 | Val Acc: 0.7110 | Time: 636.58s
# Best model saved
# Epoch 8/50 | Train Loss: 0.7863 | Val Loss: 1.1139 | Val Acc: 0.7112 | Time: 628.24s
# No improvement (1/2)
# Epoch 9/50 | Train Loss: 0.7572 | Val Loss: 1.1062 | Val Acc: 0.7155 | Time: 623.72s
# Best model saved
# Epoch 10/50 | Train Loss: 0.7321 | Val Loss: 1.1129 | Val Acc: 0.7154 | Time: 631.04s
# No improvement (1/2)
# Epoch 11/50 | Train Loss: 0.7088 | Val Loss: 1.1196 | Val Acc: 0.7116 | Time: 627.00s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 6906.95s

# %% [markdown]
# After training plot some graphs to make sure it plateaued

# %%
import json

with open("history_linear.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_linear.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_linear.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_linear.png"))
display(Image.open("accuracy_curve_linear.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# Then we start PEFT by doing BatchNorm equivalent, LayerNorm Tuning For ViT. This is fastest one so done first.

# %%
import torch.nn as nn

# Freeze everything
for param in model.parameters():
    param.requires_grad = False
    
# Unfreeze classifier
for p in model.heads.parameters():
    p.requires_grad = True

# Unfreeze LayerNorm (ViT equivalent of BN tuning)
for m in model.modules():
    if isinstance(m, nn.LayerNorm):
        if m.weight is not None:
            m.weight.requires_grad = True
        if m.bias is not None:
            m.bias.requires_grad = True
        
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-3
)
# Out:
# cuda

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="batch_norm_model.pth"
)

#Save history locally in case of kernel crash
with open("history_bn.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.1884 | Val Loss: 1.0745 | Val Acc: 0.7150 | Time: 852.88s
# Best model saved
# Epoch 2/50 | Train Loss: 0.9079 | Val Loss: 0.9977 | Val Acc: 0.7402 | Time: 854.02s
# Best model saved
# Epoch 3/50 | Train Loss: 0.7830 | Val Loss: 0.9715 | Val Acc: 0.7461 | Time: 851.33s
# Best model saved
# Epoch 4/50 | Train Loss: 0.6954 | Val Loss: 0.9758 | Val Acc: 0.7475 | Time: 848.20s
# No improvement (1/2)
# Epoch 5/50 | Train Loss: 0.6268 | Val Loss: 0.9746 | Val Acc: 0.7508 | Time: 847.24s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 4254.79s

# %% [markdown]
# Plotting again to make sure plateaued

# %%
import json

with open("history_bn.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# Next should be Task Specific Adapters

# %%
import torch.nn as nn

class Adapter(nn.Module):
    def __init__(self, dim, reduction=16):
        super().__init__()
        self.down = nn.Linear(dim, dim // reduction)
        self.up = nn.Linear(dim // reduction, dim)

    def forward(self, x):
        return x + self.up(torch.relu(self.down(x)))
    
class ViTWithAdapter(nn.Module):
    def __init__(self, model, num_classes=101):
        super().__init__()
        self.model = model
        self.adapter = Adapter(model.heads.head.in_features)
        self.head = nn.Linear(model.heads.head.in_features, num_classes)

    def forward(self, x):
        x = self.model._process_input(x)
        n = x.shape[0]
        cls_token = self.model.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)

        x = self.model.encoder(x)

        x = x[:, 0]

        x = self.adapter(x)

        return self.head(x)
    

weights = ViT_B_16_Weights.IMAGENET1K_V1
base_model = vit_b_16(weights=weights)

adapter_model = ViTWithAdapter(base_model, num_classes=101)
    
for p in adapter_model.parameters():
    p.requires_grad = False
    
for p in adapter_model.adapter.parameters():
    p.requires_grad = True

for p in adapter_model.head.parameters():
    p.requires_grad = True
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
adapter_model = adapter_model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, adapter_model.parameters()),
    lr=1e-3
)
# Out:
# cuda

# %%
import json
history = train_model(
    adapter_model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="adapter_model.pth"
)

#Save history locally in case of kernel crash
with open("history_adapter.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.7023 | Val Loss: 1.3054 | Val Acc: 0.6538 | Time: 610.76s
# Best model saved
# Epoch 2/50 | Train Loss: 1.1514 | Val Loss: 1.2049 | Val Acc: 0.6784 | Time: 621.27s
# Best model saved
# Epoch 3/50 | Train Loss: 1.0097 | Val Loss: 1.1624 | Val Acc: 0.6974 | Time: 617.80s
# Best model saved
# Epoch 4/50 | Train Loss: 0.9219 | Val Loss: 1.1669 | Val Acc: 0.6967 | Time: 623.52s
# No improvement (1/2)
# Epoch 5/50 | Train Loss: 0.8551 | Val Loss: 1.1717 | Val Acc: 0.6940 | Time: 623.77s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 3098.28s

# %%
import json

with open("history_adapter.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
