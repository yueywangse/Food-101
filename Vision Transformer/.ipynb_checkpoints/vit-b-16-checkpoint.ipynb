# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dansbecker/food-101")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\yueya\.cache\kagglehub\datasets\dansbecker\food-101\versions\1

# %%
import os

print(os.listdir(path))
# Out:
# ['food-101', 'food-101.zip']

# %%
from torchvision import datasets, transforms

data_dir = path + "/food-101/food-101/images"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(data_dir, transform=transform)

print(len(dataset))
print(dataset.classes[:5])
# Out:
# 101000
# ['apple_pie', 'baby_back_ribs', 'baklava', 'beef_carpaccio', 'beef_tartare']

# %%
from IPython.display import display
from torchvision.transforms.functional import to_pil_image

for i in range(5):
    img, label = dataset[i]
    img = to_pil_image(img)
    
    print(dataset.classes[label])
    display(img)
# Out:
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>
# apple_pie
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# **Below is the initialization block for all models, in case each model needs a kernel restart. There are many problems in Windows/Jupyter in this project like dataloaders, OOM, and matplotlib/training DLLs so I had to restart kernel, run the below block, and run the model I wanted.**

# %%
# Jupyter lab does not clear memory between models so if it OOMs or kernel dies rerun this initialization block every time
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dansbecker/food-101")

from torchvision import datasets, transforms

data_dir = path + "/food-101/food-101/images"

transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor()
])

dataset = datasets.ImageFolder(data_dir, transform=transform)

import torch
import torch.nn as nn
from torch.utils.data import DataLoader
from torchvision import transforms
from torchvision.models import vit_b_16, ViT_B_16_Weights

weights = ViT_B_16_Weights.IMAGENET1K_V1

transform = weights.transforms()

import os
from PIL import Image
from torch.utils.data import Dataset

class Food101Dataset(Dataset):
    def __init__(self, root, split_file, transform=None):
        self.root = root
        self.transform = transform
        
        with open(split_file) as f:
            self.samples = f.read().splitlines()
        
        self.classes = sorted(set(x.split('/')[0] for x in self.samples))
        self.class_to_idx = {c: i for i, c in enumerate(self.classes)}

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        item = self.samples[idx]
        label_name = item.split('/')[0]
        
        img_path = os.path.join(self.root, "images", item + ".jpg")
        img = Image.open(img_path).convert("RGB")
        
        if self.transform:
            img = self.transform(img)
        
        label = self.class_to_idx[label_name]
        return img, label
    
    
# Train/Test split

base_path = path + "/food-101/food-101"

train_dataset = Food101Dataset(
    root=base_path,
    split_file=base_path + "/meta/train.txt",
    transform=transform
)

test_dataset = Food101Dataset(
    root=base_path,
    split_file=base_path + "/meta/test.txt",
    transform=transform
)

# Model setup

model = vit_b_16(weights=weights)
model.heads.head = nn.Linear(model.heads.head.in_features, 101)

# Train/Validation from Training set split

from torch.utils.data import random_split
import random
import numpy as np

seed = 77 # Set a seed so sets are the same each time, as every model causes kernel crash if I try to continue

random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size

train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=0, pin_memory = True)
val_loader = DataLoader(val_dataset, batch_size=128, shuffle=False, num_workers=0, pin_memory = True)

# Training function

import torch
import time

def train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=20,
    patience=3,
    save_path="best_linear_model_vit.pth"
):
    best_val_loss = float('inf')
    counter = 0

    history = {
        "train_loss": [],
        "val_loss": [],
        "val_acc": [],
        "epoch_time": []
    }

    total_start = time.time()  # Total training time

    for epoch in range(epochs):
        epoch_start = time.time()  # Start epoch timer

        # Train
        model.train()
        train_loss = 0

        for imgs, labels in train_loader:
            imgs, labels = imgs.to(device, non_blocking=True), labels.to(device, non_blocking=True)

            optimizer.zero_grad()
            outputs = model(imgs)
            loss = criterion(outputs, labels)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()

        train_loss /= len(train_loader)

        # Validate
        model.eval()
        val_loss = 0
        correct = 0
        total = 0

        with torch.no_grad():
            for imgs, labels in val_loader:
                imgs, labels = imgs.to(device), labels.to(device)

                outputs = model(imgs)
                loss = criterion(outputs, labels)

                val_loss += loss.item()

                preds = outputs.argmax(dim=1)
                correct += (preds == labels).sum().item()
                total += labels.size(0)

        val_loss /= len(val_loader)
        val_acc = correct / total

        # Compute epoch time
        epoch_time = time.time() - epoch_start
        history["epoch_time"].append(epoch_time)
        
        history["train_loss"].append(train_loss)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)

        print(f"Epoch {epoch+1}/{epochs} | "
              f"Train Loss: {train_loss:.4f} | "
              f"Val Loss: {val_loss:.4f} | "
              f"Val Acc: {val_acc:.4f} | "
              f"Time: {epoch_time:.2f}s")

        # Early Stopping
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            counter = 0

            torch.save(model.state_dict(), save_path)
            print("Best model saved")

        else:
            counter += 1
            print(f"No improvement ({counter}/{patience})")

            if counter >= patience:
                print("Early stopping triggered")
                break

    # Total time
    total_time = time.time() - total_start
    print(f"\nTotal training time: {total_time:.2f}s")

    history["total_time"] = total_time

    return history

# %% [markdown]
# **First we start with linear probing, which is freezing all parameters and then unfreezing just the classifier**

# %%
for param in model.parameters():
    param.requires_grad = False

for param in model.heads.parameters():
    param.requires_grad = True
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.heads.parameters(), lr=1e-3)
# Out:
# cuda

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2
)

#Looking at task manager takes around 2 gb of vram

# Save history locally in case of kernel crash
with open("history_linear.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.8384 | Val Loss: 1.3949 | Val Acc: 0.6430 | Time: 490.31s
# Best model saved
# Epoch 2/50 | Train Loss: 1.2171 | Val Loss: 1.2461 | Val Acc: 0.6815 | Time: 478.35s
# Best model saved
# Epoch 3/50 | Train Loss: 1.0675 | Val Loss: 1.1801 | Val Acc: 0.6942 | Time: 476.99s
# Best model saved
# Epoch 4/50 | Train Loss: 0.9759 | Val Loss: 1.1529 | Val Acc: 0.6985 | Time: 477.81s
# Best model saved
# Epoch 5/50 | Train Loss: 0.9115 | Val Loss: 1.1279 | Val Acc: 0.7062 | Time: 487.12s
# Best model saved
# Epoch 6/50 | Train Loss: 0.8605 | Val Loss: 1.1220 | Val Acc: 0.7065 | Time: 484.26s
# Best model saved
# Epoch 7/50 | Train Loss: 0.8211 | Val Loss: 1.1202 | Val Acc: 0.7067 | Time: 480.93s
# Best model saved
# Epoch 8/50 | Train Loss: 0.7858 | Val Loss: 1.1201 | Val Acc: 0.7119 | Time: 478.39s
# Best model saved
# Epoch 9/50 | Train Loss: 0.7559 | Val Loss: 1.1213 | Val Acc: 0.7083 | Time: 482.10s
# No improvement (1/2)
# Epoch 10/50 | Train Loss: 0.7319 | Val Loss: 1.1161 | Val Acc: 0.7114 | Time: 482.16s
# Best model saved
# Epoch 11/50 | Train Loss: 0.7076 | Val Loss: 1.1249 | Val Acc: 0.7094 | Time: 492.93s
# No improvement (1/2)
# Epoch 12/50 | Train Loss: 0.6878 | Val Loss: 1.1284 | Val Acc: 0.7079 | Time: 482.67s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 5796.99s

# %% [markdown]
# **After training plot some graphs to make sure it plateaued**

# %%
import json

with open("history_linear.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_linear.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_linear.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_linear.png"))
display(Image.open("accuracy_curve_linear.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# **Then we start PEFT by doing BatchNorm equivalent, LayerNorm Tuning For ViT. This is simplest one so done first.**

# %%
import torch.nn as nn

# Freeze everything
for param in model.parameters():
    param.requires_grad = False
    
# Unfreeze classifier
for p in model.heads.parameters():
    p.requires_grad = True

# Unfreeze LayerNorm (ViT equivalent of BN tuning)
for m in model.modules():
    if isinstance(m, nn.LayerNorm):
        if m.weight is not None:
            m.weight.requires_grad = True
        if m.bias is not None:
            m.bias.requires_grad = True
        
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-3
)
# Out:
# cuda

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="batch_norm_model.pth"
)

#Looking at task manager takes around 10.5 gb of vram

#Save history locally in case of kernel crash
with open("history_bn.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.5066 | Val Loss: 1.0499 | Val Acc: 0.7262 | Time: 672.22s
# Best model saved
# Epoch 2/50 | Train Loss: 0.8541 | Val Loss: 0.9216 | Val Acc: 0.7568 | Time: 670.10s
# Best model saved
# Epoch 3/50 | Train Loss: 0.6972 | Val Loss: 0.8951 | Val Acc: 0.7654 | Time: 669.34s
# Best model saved
# Epoch 4/50 | Train Loss: 0.5946 | Val Loss: 0.9038 | Val Acc: 0.7615 | Time: 672.62s
# No improvement (1/2)
# Epoch 5/50 | Train Loss: 0.5199 | Val Loss: 0.9223 | Val Acc: 0.7630 | Time: 667.24s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 3352.43s

# %% [markdown]
# Plotting again to make sure plateaued

# %%
import json

with open("history_bn.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# **Next should be Task Specific Adapters**

# %%
import torch.nn as nn

class Adapter(nn.Module):
    def __init__(self, dim, reduction=16):
        super().__init__()
        self.down = nn.Linear(dim, dim // reduction)
        self.up = nn.Linear(dim // reduction, dim)

    def forward(self, x):
        return x + self.up(torch.relu(self.down(x)))
    
class ViTWithAdapter(nn.Module):
    def __init__(self, model, num_classes=101):
        super().__init__()
        self.model = model
        self.adapter = Adapter(model.heads.head.in_features)
        self.head = nn.Linear(model.heads.head.in_features, num_classes)

    def forward(self, x):
        x = self.model._process_input(x)
        n = x.shape[0]
        cls_token = self.model.class_token.expand(n, -1, -1)
        x = torch.cat((cls_token, x), dim=1)

        x = self.model.encoder(x)

        x = x[:, 0]

        x = self.adapter(x)

        return self.head(x)
    

weights = ViT_B_16_Weights.IMAGENET1K_V1
base_model = vit_b_16(weights=weights)

adapter_model = ViTWithAdapter(base_model, num_classes=101)
    
for p in adapter_model.parameters():
    p.requires_grad = False
    
for p in adapter_model.adapter.parameters():
    p.requires_grad = True

for p in adapter_model.head.parameters():
    p.requires_grad = True
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
adapter_model = adapter_model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, adapter_model.parameters()),
    lr=1e-3
)
# Out:
# cuda

# %%
import json
history = train_model(
    adapter_model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="adapter_model.pth"
)

#Looking at task manager takes around 2 gb of vram

#Save history locally in case of kernel crash
with open("history_adapter.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.7004 | Val Loss: 1.3218 | Val Acc: 0.6538 | Time: 487.76s
# Best model saved
# Epoch 2/50 | Train Loss: 1.1460 | Val Loss: 1.2212 | Val Acc: 0.6780 | Time: 486.42s
# Best model saved
# Epoch 3/50 | Train Loss: 1.0041 | Val Loss: 1.1988 | Val Acc: 0.6853 | Time: 479.99s
# Best model saved
# Epoch 4/50 | Train Loss: 0.9169 | Val Loss: 1.1880 | Val Acc: 0.6929 | Time: 483.29s
# Best model saved
# Epoch 5/50 | Train Loss: 0.8532 | Val Loss: 1.1880 | Val Acc: 0.6904 | Time: 480.42s
# No improvement (1/2)
# Epoch 6/50 | Train Loss: 0.7987 | Val Loss: 1.2069 | Val Acc: 0.6931 | Time: 478.00s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 2897.11s

# %%
import json

with open("history_adapter.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# **Finally we can do LoRA, it's different for ViT, like BatchNorm, and requires a bit of modification to make it a bit easier**

# %%
import torch
import torch.nn as nn

class LoRALinear(nn.Module):
    def __init__(self, linear, r=4, alpha=1.0):
        super().__init__()
        self.linear = linear  # original frozen layer
        self.r = r
        self.alpha = alpha

        in_dim = linear.in_features
        out_dim = linear.out_features

        # LoRA matrices
        self.A = nn.Linear(in_dim, r, bias=False)
        self.B = nn.Linear(r, out_dim, bias=False)

        # scale
        self.scaling = alpha / r

        # freeze original
        for p in self.linear.parameters():
            p.requires_grad = False

    def forward(self, x):
        return self.linear(x) + self.B(self.A(x)) * self.scaling
    
def apply_lora(model, r=4):
    for name, module in list(model.named_modules()):

        if "mlp" in name and "fc1" in name and isinstance(module, nn.Linear):

            parent = model
            *path, last = name.split(".")

            for p in path:
                parent = getattr(parent, p)

            setattr(parent, last, LoRALinear(module, r=r))

# %%
from torchvision.models import vit_b_16, ViT_B_16_Weights
import torch.nn as nn

weights = ViT_B_16_Weights.IMAGENET1K_V1
model = vit_b_16(weights=weights)

in_dim = model.heads.head.in_features
model.heads.head = nn.Linear(in_dim, 101)

apply_lora(model, r=8)

for p in model.parameters():
    p.requires_grad = False

for m in model.modules():
    if isinstance(m, LoRALinear):
        for p in m.parameters():
            p.requires_grad = True

for p in model.heads.parameters():
    p.requires_grad = True
    
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(
    filter(lambda p: p.requires_grad, model.parameters()),
    lr=1e-4 # LoRA needs 
)
# Out:
# cuda

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="lora_model.pth"
)

#Looking at task manager only takes around 2 gb of vram

#Save history locally in case of kernel crash
with open("history_lora.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 3.4309 | Val Loss: 2.6089 | Val Acc: 0.4827 | Time: 481.92s
# Best model saved
# Epoch 2/50 | Train Loss: 2.2730 | Val Loss: 2.0270 | Val Acc: 0.5566 | Time: 464.69s
# Best model saved
# Epoch 3/50 | Train Loss: 1.8904 | Val Loss: 1.7795 | Val Acc: 0.5899 | Time: 471.87s
# Best model saved
# Epoch 4/50 | Train Loss: 1.6967 | Val Loss: 1.6386 | Val Acc: 0.6098 | Time: 475.01s
# Best model saved
# Epoch 5/50 | Train Loss: 1.5732 | Val Loss: 1.5431 | Val Acc: 0.6247 | Time: 468.12s
# Best model saved
# Epoch 6/50 | Train Loss: 1.4853 | Val Loss: 1.4752 | Val Acc: 0.6397 | Time: 464.21s
# Best model saved
# Epoch 7/50 | Train Loss: 1.4177 | Val Loss: 1.4219 | Val Acc: 0.6489 | Time: 464.90s
# Best model saved
# Epoch 8/50 | Train Loss: 1.3626 | Val Loss: 1.3808 | Val Acc: 0.6581 | Time: 466.48s
# Best model saved
# Epoch 9/50 | Train Loss: 1.3167 | Val Loss: 1.3462 | Val Acc: 0.6641 | Time: 472.17s
# Best model saved
# Epoch 10/50 | Train Loss: 1.2775 | Val Loss: 1.3169 | Val Acc: 0.6721 | Time: 465.93s
# Best model saved
# Epoch 11/50 | Train Loss: 1.2430 | Val Loss: 1.2924 | Val Acc: 0.6756 | Time: 463.00s
# Best model saved
# Epoch 12/50 | Train Loss: 1.2131 | Val Loss: 1.2712 | Val Acc: 0.6795 | Time: 462.30s
# Best model saved
# Epoch 13/50 | Train Loss: 1.1861 | Val Loss: 1.2524 | Val Acc: 0.6855 | Time: 472.34s
# Best model saved
# Epoch 14/50 | Train Loss: 1.1624 | Val Loss: 1.2358 | Val Acc: 0.6887 | Time: 468.14s
# Best model saved
# Epoch 15/50 | Train Loss: 1.1399 | Val Loss: 1.2216 | Val Acc: 0.6907 | Time: 469.37s
# Best model saved
# Epoch 16/50 | Train Loss: 1.1192 | Val Loss: 1.2086 | Val Acc: 0.6941 | Time: 476.82s
# Best model saved
# Epoch 17/50 | Train Loss: 1.1006 | Val Loss: 1.1963 | Val Acc: 0.6955 | Time: 465.64s
# Best model saved
# Epoch 18/50 | Train Loss: 1.0831 | Val Loss: 1.1855 | Val Acc: 0.6982 | Time: 463.21s
# Best model saved
# Epoch 19/50 | Train Loss: 1.0668 | Val Loss: 1.1753 | Val Acc: 0.7009 | Time: 463.66s
# Best model saved
# Epoch 20/50 | Train Loss: 1.0518 | Val Loss: 1.1661 | Val Acc: 0.7032 | Time: 463.08s
# Best model saved
# Epoch 21/50 | Train Loss: 1.0378 | Val Loss: 1.1582 | Val Acc: 0.7031 | Time: 460.40s
# Best model saved
# Epoch 22/50 | Train Loss: 1.0242 | Val Loss: 1.1504 | Val Acc: 0.7061 | Time: 462.19s
# Best model saved
# Epoch 23/50 | Train Loss: 1.0114 | Val Loss: 1.1432 | Val Acc: 0.7083 | Time: 459.98s
# Best model saved
# Epoch 24/50 | Train Loss: 0.9993 | Val Loss: 1.1380 | Val Acc: 0.7083 | Time: 460.59s
# Best model saved
# Epoch 25/50 | Train Loss: 0.9877 | Val Loss: 1.1308 | Val Acc: 0.7095 | Time: 462.39s
# Best model saved
# Epoch 26/50 | Train Loss: 0.9769 | Val Loss: 1.1254 | Val Acc: 0.7104 | Time: 477.69s
# Best model saved
# Epoch 27/50 | Train Loss: 0.9666 | Val Loss: 1.1208 | Val Acc: 0.7105 | Time: 457.42s
# Best model saved
# Epoch 28/50 | Train Loss: 0.9563 | Val Loss: 1.1163 | Val Acc: 0.7119 | Time: 458.93s
# Best model saved
# Epoch 29/50 | Train Loss: 0.9473 | Val Loss: 1.1110 | Val Acc: 0.7131 | Time: 459.48s
# Best model saved
# Epoch 30/50 | Train Loss: 0.9381 | Val Loss: 1.1072 | Val Acc: 0.7139 | Time: 464.47s
# Best model saved
# Epoch 31/50 | Train Loss: 0.9294 | Val Loss: 1.1031 | Val Acc: 0.7137 | Time: 463.17s
# Best model saved
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import json
# ----> 2 history = train_model(
#       3     model,
#       4     train_loader,
#       5     val_loader,
#       6     criterion,
#       7     optimizer,
#       8     device,
#       9     epochs=50,
#      10     patience=2,
#      11     save_path="lora_model.pth"
#      12 )
#      14 #Save history locally in case of kernel crash
#      15 with open("history_lora.json", "w") as f:
#
# Cell In[2], line 149, in train_model(model, train_loader, val_loader, criterion, optimizer, device, epochs, patience, save_path)
#     146 total = 0
#     148 with torch.no_grad():
# --> 149     for imgs, labels in val_loader:
#     150         imgs, labels = imgs.to(device), labels.to(device)
#     152         outputs = model(imgs)
#
# File ~\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:741, in _BaseDataLoaderIter.__next__(self)
#     738 if self._sampler_iter is None:
#     739     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     740     self._reset()  # type: ignore[call-arg]
# --> 741 data = self._next_data()
#     742 self._num_yielded += 1
#     743 if (
#     744     self._dataset_kind == _DatasetKind.Iterable
#     745     and self._IterableDataset_len_called is not None
#     746     and self._num_yielded > self._IterableDataset_len_called
#     747 ):
#
# File ~\miniconda3\Lib\site-packages\torch\utils\data\dataloader.py:801, in _SingleProcessDataLoaderIter._next_data(self)
#     799 def _next_data(self):
#     800     index = self._next_index()  # may raise StopIteration
# --> 801     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     802     if self._pin_memory:
#     803         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~\miniconda3\Lib\site-packages\torch\utils\data\_utils\fetch.py:52, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      50 if self.auto_collation:
#      51     if hasattr(self.dataset, "__getitems__") and self.dataset.__getitems__:
# ---> 52         data = self.dataset.__getitems__(possibly_batched_index)
#      53     else:
#      54         data = [self.dataset[idx] for idx in possibly_batched_index]
#
# File ~\miniconda3\Lib\site-packages\torch\utils\data\dataset.py:443, in Subset.__getitems__(self, indices)
#     441     return self.dataset.__getitems__([self.indices[idx] for idx in indices])  # type: ignore[attr-defined]
#     442 else:
# --> 443     return [self.dataset[self.indices[idx]] for idx in indices]
#
# Cell In[2], line 51, in Food101Dataset.__getitem__(self, idx)
#      48 label_name = item.split('/')[0]
#      50 img_path = os.path.join(self.root, "images", item + ".jpg")
# ---> 51 img = Image.open(img_path).convert("RGB")
#      53 if self.transform:
#      54     img = self.transform(img)
#
# File ~\miniconda3\Lib\site-packages\PIL\Image.py:986, in Image.convert(self, mode, matrix, dither, palette, colors)
#     983 if mode in ("BGR;15", "BGR;16", "BGR;24"):
#     984     deprecate(mode, 12)
# --> 986 self.load()
#     988 has_transparency = "transparency" in self.info
#     989 if not mode and self.mode == "P":
#     990     # determine default mode
#
# File ~\miniconda3\Lib\site-packages\PIL\ImageFile.py:390, in ImageFile.load(self)
#     387         raise OSError(msg)
#     389 b = b + s
# --> 390 n, err_code = decoder.decode(b)
#     391 if n < 0:
#     392     break
#
# KeyboardInterrupt:

# %% [markdown]
# **Halted manually as it was taking too long and was good enough**

# %%
import json

with open("history_lora.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>

# %% [markdown]
# **The final training we do is full fine tuning, essentially leaving all weights unfrozen**

# %%
from torchvision.models import vit_b_16, ViT_B_16_Weights
import torch.nn as nn

weights = ViT_B_16_Weights.IMAGENET1K_V1
model = vit_b_16(weights=weights)

# replace classifier
in_dim = model.heads.head.in_features
model.heads.head = nn.Linear(in_dim, 101)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
model = model.to(device)

criterion = nn.CrossEntropyLoss()

optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# Out:
# cuda

# %%
import json
history = train_model(
    model,
    train_loader,
    val_loader,
    criterion,
    optimizer,
    device,
    epochs=50,
    patience=2,
    save_path="full_model.pth"
)

#Looking at task manager takes around 16.9 gb of vram

#Save history locally in case of kernel crash
with open("history_full.json", "w") as f:
    json.dump(history, f)
# Out:
# Epoch 1/50 | Train Loss: 1.5343 | Val Loss: 1.0164 | Val Acc: 0.7404 | Time: 728.57s
# Best model saved
# Epoch 2/50 | Train Loss: 0.6303 | Val Loss: 0.9243 | Val Acc: 0.7588 | Time: 723.84s
# Best model saved
# Epoch 3/50 | Train Loss: 0.3320 | Val Loss: 0.9605 | Val Acc: 0.7577 | Time: 725.19s
# No improvement (1/2)
# Epoch 4/50 | Train Loss: 0.1854 | Val Loss: 0.9559 | Val Acc: 0.7653 | Time: 722.21s
# No improvement (2/2)
# Early stopping triggered
#
# Total training time: 2900.40s

# %%
import json

with open("history_full.json", "r") as f:
    history = json.load(f)
    
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history["train_loss"], label="Train Loss")
plt.plot(history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Loss Curve")
plt.legend()
plt.grid()

plt.savefig("loss_curve_bn.png")

plt.figure()
plt.plot(history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Validation Accuracy")
plt.legend()
plt.grid()

plt.savefig("accuracy_curve_bn.png")

# %%
from PIL import Image
from IPython.display import display

display(Image.open("loss_curve_bn.png"))
display(Image.open("accuracy_curve_bn.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=640x480>
